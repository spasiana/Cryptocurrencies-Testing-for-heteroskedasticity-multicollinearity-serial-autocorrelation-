# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
import statsmodels.stats
from statsmodels.tsa.stattools import adfuller
import seaborn as sns
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.stattools import durbin_watson
pd.options.display.float_format = '{:.6f}'.format # displayformat -> sientific to float
from statsmodels.stats.outliers_influence import variance_inflation_factor
import itertools

import statsmodels.stats
import math
from statsmodels.tsa.stattools import adfuller
import seaborn as sns
import itertools

# %%
import sqlite3
from sqlite3 import Error
 

""" create a database connection tool to a SQLite database """

def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()
 
 
if __name__ == '__main__':
    create_connection(r"C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db")
# Out:
# 2.6.0

# %%
conn = sqlite3.connect(r"C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db")

print("Opened database successfully")
# Out:
# Opened database successfully

# %% [markdown]
# # Name major of Dataframes
#
# MCdf= Master Crypto Dataframe
#
# MFdf = Master Fiat Dataframe
#
# MCMdf = Master Commodity Dataframe
#
# MIdf = Master Index Dataframe
#
# MAdf = Master all Dataframe

# %%
#import first (Bitcoin) Dataset
dfBTC = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Bitcoin.csv', sep=';')

# %%
#import first (Bitcoin) Dataset
dfBTC = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Bitcoin.csv', sep=';')

#import second (Bitcoin Cash) Dataset
dfBCH = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Bitcoin Cash.csv', sep=';')

# Creation of MASTER DATAFRAME MDF
Mdf= pd.merge(dfBTC, dfBCH, how="outer")

#import (Litecoin) and Ethirum Dataset
dfLTC = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Litecoin.csv', sep=';')
dfETH = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\\Ethirum.csv', sep=';')

#Merge LTH and ETH with the MASTER DF
Mdf2= pd.merge(Mdf, dfLTC, how="outer")
Mdf3=pd.merge(Mdf2, dfETH, how="outer")

#Load all Fiat Currencys EUR CHF RUB YEN SEK GB
dfEUR = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Euro.csv', sep=';')
dfCHF = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Schweizer Franken.csv', sep=';')
dfRUB = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Rubel.csv', sep=';')
dfGBP = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Pfund.csv', sep=';')
dfYEN = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Yen.csv', sep=';')
dfSEK = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Schwedische Kronen.csv', sep=';')

#Rename Mdf3 to MasterCrypto DF MCdf
MCdf= Mdf3

# Creation of Master Fiat DF MFdf
Fdf1= pd.merge(dfEUR, dfCHF, how="outer")
Fdf2= pd.merge(Fdf1, dfGBP, how="outer")
Fdf3= pd.merge(Fdf2, dfRUB, how="outer")
Fdf4= pd.merge(Fdf3, dfYEN, how="outer")
Fdf5= pd.merge(Fdf4, dfSEK, how="outer")
MFdf=Fdf5

#Load all Commodities Gold, Silver, Palladium, Platinum, Brent Crude Oil
dfGold = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Gold.csv', sep=';')
dfSilver= pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Silver.csv', sep=';')
dfPalladium = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Palladium.csv', sep=';')
dfPlatinum = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Platinum.csv', sep=';')
dfOil = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\Brent Crude Oil.csv', sep=';')

# Creation of Master Commodity DF MCMdf
CMdf1= pd.merge(dfGold, dfSilver, how="outer")
CMdf2= pd.merge(CMdf1, dfPalladium, how="outer")
CMdf3= pd.merge(CMdf2, dfPlatinum, how="outer")
CMdf4= pd.merge(CMdf3, dfOil, how="outer")
MCMdf=CMdf4

#Load all Market Index, MSCI, FTSE 100, NASDAQ, DAX,SMI, 
dfMSCI = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\MSCI.csv', sep=';')
dfFTSE= pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\FTSE 100.csv', sep=';')
dfNASDAQ = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\NASDAQ.csv', sep=';')
dfDAX = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\DAX.csv', sep=';')
dfSMI = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\SMI.csv', sep=';')

# Creation of Master INDEX DF MIdf
Idf1= pd.merge(dfMSCI, dfFTSE, how="outer")
Idf2= pd.merge(Idf1, dfNASDAQ, how="outer")
Idf3= pd.merge(Idf2, dfDAX, how="outer")
Idf4= pd.merge(Idf3, dfSMI, how="outer")
MIdf=Idf4

#Create one Master DF with all DF MCdf MFdf MCMdf   MIdf
Adf1= pd.merge(MCdf, MFdf, how="outer")
Adf2= pd.merge(Adf1, MCMdf, how="outer")
Adf3= pd.merge(Adf2,  MIdf, how="outer")
MAdf=Adf3

# %%
# Analysis of the MAdf
MAdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1019 entries, 0 to 1018
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1019 non-null   object
#  1   BTC        791 non-null    float64
#  2   BCH        791 non-null    float64
#  3   LTC        791 non-null    float64
#  4   ETH        791 non-null    float64
#  5   EUR        791 non-null    float64
#  6   CHF        791 non-null    float64
#  7   GBP        791 non-null    float64
#  8   RUB        791 non-null    float64
#  9   YEN        791 non-null    float64
#  10  SEK        791 non-null    float64
#  11  Gold       565 non-null    float64
#  12  Silver     565 non-null    float64
#  13  Palladium  563 non-null    float64
#  14  Platinum   563 non-null    float64
#  15  OIL        546 non-null    float64
#  16  MSCI       567 non-null    float64
#  17  FTSE 100   548 non-null    float64
#  18  NASDAQ     545 non-null    float64
# ...

# %%
#check for NA
MAdf.isna().sum()
# Out:
# Date           0
# BTC          228
# BCH          228
# LTC          228
# ETH          228
# EUR          228
# CHF          228
# GBP          228
# RUB          228
# YEN          228
# SEK          228
# Gold         454
# Silver       454
# Palladium    456
# Platinum     456
# OIL          473
# MSCI         452
# FTSE 100     471
# NASDAQ       474
# DAX          475
# SMI          479
# dtype: int64

# %%
# Safe as CSV
MAdf.to_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\AQSData1.csv')
# Data aufbereitung
DF = pd.read_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\AQSData1.csv', sep=',')
DF= DF.drop('Unnamed: 0', axis=1)
DF = DF.iloc[:-240]# because last 240 rows -> only index has values
DF = DF.fillna(method='bfill') #use Backward or Forward fill to replace NA ->  df = df.fillna(method='ffill') / bfill
DF
# Out:
#            Date          BTC        BCH        LTC        ETH      EUR  \
# 0    01.01.2021 29260.250000 339.550000 125.540000 729.720000 1.221200
# 1    31.12.2020 28987.600000 343.040000 124.070000 738.870000 1.221300
# 2    30.12.2020 28911.000000 355.750000 127.520000 748.170000 1.229500
# 3    29.12.2020 26893.110000 348.550000 126.170000 724.330000 1.224700
# 4    28.12.2020 26584.870000 358.090000 129.010000 726.740000 1.221400
# ..          ...          ...        ...        ...        ...      ...
# 774  19.11.2018  4778.570000 323.340000  35.730000 147.270000 1.145100
# 775  18.11.2018  5527.590000 385.950000  41.810000 177.320000 1.141800
# 776  17.11.2018  5484.110000 390.400000  41.440000 171.950000 1.141800
# 777  16.11.2018  5448.470000 385.740000  41.750000 174.850000 1.141800
# 778  15.11.2018  5468.880000 391.840000  43.400000 177.210000 1.132600
#
#          CHF      GBP       RUB        YEN  ...        Gold    Silver  \
# ...

# %% [markdown]
# # Data is OKEY

# %%
#save Dataframe into SQL
conn = sqlite3.connect(r"C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db")

# Write the new DataFrame to a new SQLite table
DF.to_sql("AQMDataBfill", conn, if_exists="replace")
conn.close()
# Out:
# C:\Users\HPspectre\anaconda3new\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
DF['Date'] = pd.to_datetime(DF['Date'])
DF.set_index('Date', inplace=True)
DF.tail()
# Out:
#                    BTC        BCH       LTC        ETH      EUR      CHF  \
# Date
# 2018-11-19 4778.570000 323.340000 35.730000 147.270000 1.145100 0.993500
# 2018-11-18 5527.590000 385.950000 41.810000 177.320000 1.141800 0.999700
# 2018-11-17 5484.110000 390.400000 41.440000 171.950000 1.141800 0.999700
# 2018-11-16 5448.470000 385.740000 41.750000 174.850000 1.141800 0.999700
# 2018-11-15 5468.880000 391.840000 43.400000 177.210000 1.132600 1.006900
#
#                 GBP       RUB        YEN      SEK        Gold    Silver  \
# Date
# 2018-11-19 1.284900 65.605000 112.540000 9.001200 1223.980000 14.422000
# 2018-11-18 1.283700 65.925000 112.820000 9.004200 1221.390000 14.410000
# 2018-11-17 1.283700 65.925000 112.820000 9.004200 1221.390000 14.410000
# 2018-11-16 1.283700 65.925000 112.820000 9.004200 1221.390000 14.410000
# 2018-11-15 1.277400 65.860000 113.620000 9.062400 1212.910000 14.286000
#
#              Palladium   Platinum       OIL        MSCI    FTSE 100  \
# Date
# ...

# %% [markdown]
# # Try to make Stationary only with first difference
# this is not important for the Assignment: -> we use log data

# %%
# Create new Dataframe and safe it as 1 Difference Dataframe
d_df=DF.copy()

# Create header list
DF_header_list1 = list(DF.columns.values)
d_df_header_list = []

for i in DF.columns.values:
    d_df_header_list.append(str(i + "_d"))


DF_header_list1 
d_df_header_list
# Out:
# ['BTC_d',
#  'BCH_d',
#  'LTC_d',
#  'ETH_d',
#  'EUR_d',
#  'CHF_d',
#  'GBP_d',
#  'RUB_d',
#  'YEN_d',
#  'SEK_d',
#  'Gold_d',
#  'Silver_d',
#  'Palladium_d',
#  'Platinum_d',
#  'OIL_d',
#  'MSCI_d',
#  'FTSE 100_d',
#  'NASDAQ_d',
#  'DAX_d',
#  'SMI_d']

# %%
d_df['BTC_shift']=d_df['BTC'].shift(periods = 1)
d_df['BCH_shift']=d_df['BCH'].shift(periods = 1) 
d_df['LTC_shift']=d_df['LTC'].shift(periods = 1) 
d_df['ETH_shift']=d_df['ETH'].shift(periods = 1) 
d_df['EUR_shift']=d_df['EUR'].shift(periods = 1) 
d_df['CHF_shift']=d_df['CHF'].shift(periods = 1) 
d_df['GBP_shift']=d_df['GBP'].shift(periods = 1) 
d_df['RUB_shift']=d_df['RUB'].shift(periods = 1) 
d_df['YEN_shift']=d_df['YEN'].shift(periods = 1) 
d_df['SEK_shift']=d_df['SEK'].shift(periods = 1) 
d_df['Gold_shift']=d_df['Gold'].shift(periods = 1) 
d_df['Silver_shift']=d_df['Silver'].shift(periods = 1) 
d_df['Palladium_shift']=d_df['Palladium'].shift(periods = 1) 
d_df['Platinum_shift']=d_df['Platinum'].shift(periods = 1) 
d_df['OIL_shift']=d_df['OIL'].shift(periods = 1) 
d_df['MSCI_shift']=d_df['MSCI'].shift(periods = 1) 
d_df['FTSE100_shift']=d_df['FTSE 100'].shift(periods = 1) 
d_df['NASDAQ_shift']=d_df['NASDAQ'].shift(periods = 1) 
d_df['DAX_shift']=d_df['DAX'].shift(periods = 1) 
d_df['SMI_shift']=d_df['SMI'].shift(periods = 1) 

d_df['BTC_d'] = d_df['BTC'] - d_df['BTC_shift']
d_df['BCH_d'] = d_df['BCH'] - d_df['BCH_shift']
d_df['LTC_d'] = d_df['LTC'] - d_df['LTC_shift']
d_df['ETH_d'] = d_df['ETH'] - d_df['ETH_shift']
d_df['EUR_d'] = d_df['EUR'] - d_df['EUR_shift']
d_df['CHF_d'] = d_df['CHF'] - d_df['CHF_shift']
d_df['GBP_d'] = d_df['GBP'] - d_df['GBP_shift']
d_df['RUB_d'] = d_df['RUB'] - d_df['RUB_shift']
d_df['YEN_d'] = d_df['YEN'] - d_df['YEN_shift']
d_df['SEK_d'] = d_df['SEK'] - d_df['SEK_shift']
d_df['Gold_d'] = d_df['Gold'] - d_df['Gold_shift']
d_df['Silver_d'] = d_df['Silver'] - d_df['Silver_shift']
d_df['Palladium_d'] = d_df['Palladium'] - d_df['Palladium_shift']
d_df['Platinum_d'] = d_df['Platinum'] - d_df['Platinum_shift']
d_df['OIL_d'] = d_df['OIL'] - d_df['OIL_shift']
d_df['MSCI_d'] = d_df['MSCI'] - d_df['MSCI_shift']
d_df['FTSE 100_d'] = d_df['FTSE 100'] - d_df['FTSE100_shift']
d_df['NASDAQ_d'] = d_df['NASDAQ'] - d_df['NASDAQ_shift']
d_df['DAX_d'] = d_df['DAX'] - d_df['DAX_shift']
d_df['SMI_d'] = d_df['SMI'] - d_df['SMI_shift']

d_df = d_df.drop(['BTC_shift',
                  'BCH_shift', 
                  'LTC_shift',
                  'ETH_shift',
                  'EUR_shift',
                  'CHF_shift',
                  'GBP_shift',
                  'RUB_shift',
                  'YEN_shift',
                  'SEK_shift',
                  'Gold_shift',
                  'Silver_shift',
                  'Palladium_shift',
                  'Platinum_shift',
                  'OIL_shift',
                  'MSCI_shift',
                  'FTSE100_shift',
                  'NASDAQ_shift',
                  'DAX_shift',
                  'SMI_shift'], axis = 1)

# %%
d_df.head()
# Out:
#                     BTC        BCH        LTC        ETH      EUR      CHF  \
# Date
# 2021-01-01 29260.250000 339.550000 125.540000 729.720000 1.221200 0.885100
# 2020-12-31 28987.600000 343.040000 124.070000 738.870000 1.221300 0.885100
# 2020-12-30 28911.000000 355.750000 127.520000 748.170000 1.229500 0.881000
# 2020-12-29 26893.110000 348.550000 126.170000 724.330000 1.224700 0.884300
# 2020-12-28 26584.870000 358.090000 129.010000 726.740000 1.221400 0.888400
#
#                 GBP       RUB        YEN      SEK  ...     Gold_d  Silver_d  \
# Date                                               ...
# 2021-01-01 1.367100 73.790000 103.200000 8.207800  ...        nan       nan
# 2020-12-31 1.367300 73.790000 103.240000 8.214800  ...  -1.612500 -0.001600
# 2020-12-30 1.362200 74.137600 103.170000 8.196400  ...  -3.119300  0.251600
# 2020-12-29 1.350000 73.861000 103.560000 8.193700  ... -15.376400 -0.431200
# ...

# %%
#Drop all Colums which are not first difference
d1_df = d_df.drop(['BTC',
                  'BCH', 
                  'LTC',
                  'ETH',
                  'EUR',
                  'CHF',
                  'GBP',
                  'RUB',
                  'YEN',
                  'SEK',
                  'Gold',
                  'Silver',
                  'Palladium',
                  'Platinum',
                  'OIL',
                  'MSCI',
                  'FTSE 100',
                  'NASDAQ',
                  'DAX',
                  'SMI'], axis = 1)

d1_df =d1_df.iloc[1: , :]
#d_df.to_excel('AQSDataAbsolutAndD1.xlsx')
#d1_df.to_excel('AQSDataonlyD1.xlsx')
#d_df.to_csv('AQSDataD1.csv')
#d1_df.to_csv('AQSDataonlyD1.csv')

# %%
d1_df.isna().sum()
# Out:
# BTC_d          0
# BCH_d          0
# LTC_d          0
# ETH_d          0
# EUR_d          0
# CHF_d          0
# GBP_d          0
# RUB_d          0
# YEN_d          0
# SEK_d          0
# Gold_d         0
# Silver_d       0
# Palladium_d    0
# Platinum_d     0
# OIL_d          0
# MSCI_d         0
# FTSE 100_d     0
# NASDAQ_d       0
# DAX_d          0
# SMI_d          0
# dtype: int64

# %%
d1_df.head()
# Out:
#                   BTC_d      BCH_d     LTC_d      ETH_d     EUR_d     CHF_d  \
# Date
# 2020-12-31  -272.650000   3.490000 -1.470000   9.150000  0.000100  0.000000
# 2020-12-30   -76.600000  12.710000  3.450000   9.300000  0.008200 -0.004100
# 2020-12-29 -2017.890000  -7.200000 -1.350000 -23.840000 -0.004800  0.003300
# 2020-12-28  -308.240000   9.540000  2.840000   2.410000 -0.003300  0.004100
# 2020-12-27   163.920000 -11.150000  2.140000 -38.170000 -0.001000  0.000500
#
#                GBP_d     RUB_d     YEN_d     SEK_d     Gold_d  Silver_d  \
# Date
# 2020-12-31  0.000200  0.000000  0.040000  0.007000  -1.612500 -0.001600
# 2020-12-30 -0.005100  0.347600 -0.070000 -0.018400  -3.119300  0.251600
# 2020-12-29 -0.012200 -0.276600  0.390000 -0.002700 -15.376400 -0.431200
# 2020-12-28 -0.005100 -0.376700  0.220000  0.063200  -6.801800 -0.018800
# 2020-12-27  0.009900  0.525700 -0.300000 -0.025100   4.635000 -0.310000
#
# ...

# %% [markdown]
# # Test Stationarity of D1

# %%
#Stationaritäts test
def test_stationarity(timeseries): #Perform Dickey-Fuller test: 
    print('Results of Dickey-Fuller Test:') 
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], 
                         index=['Test Statistic','p-value', 
                                '#Lags Used', 
                                'Number of Observations Used']) 
    for key,value in dftest[4].items(): 
        dfoutput['Critical Value (%s)'%key] = value 
        print(dfoutput)

# %%
for i in d_df_header_list:
    d_df[i].plot(kind = 'line',
             legend = False,
             grid = True)
    plt.ylabel(i)
    plt.xlabel('Date')
    plt.show()
    test_stationarity(d_df[i][1:])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -7.102608
# p-value                         0.000000
# #Lags Used                     20.000000
# Number of Observations Used   757.000000
# Critical Value (1%)            -3.439018
# dtype: float64
# Test Statistic                 -7.102608
# p-value                         0.000000
# #Lags Used                     20.000000
# Number of Observations Used   757.000000
# Critical Value (1%)            -3.439018
# Critical Value (5%)            -2.865366
# dtype: float64
# Test Statistic                 -7.102608
# p-value                         0.000000
# #Lags Used                     20.000000
# Number of Observations Used   757.000000
# Critical Value (1%)            -3.439018
# Critical Value (5%)            -2.865366
# Critical Value (10%)           -2.568807
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -28.534193
# p-value                         0.000000
# ...

# %% [markdown]
# # Log

# %%
#Creation of Logreturns loop
DF_log = DF.copy()

# create list of names for log return columns
DF_header_list2 = list(DF.columns.values)
DF_header_log_list = []
for i in DF.columns.values:
    DF_header_log_list.append(str(i + "_log"))

    
for i in range(len(DF_header_list2)):
    DF_log[DF_header_log_list[i]] = np.log(DF_log[DF_header_list2[i]]) - np.log(DF_log[DF_header_list2[i]].shift(1))

# %%
# Safe this Dataframe -> Database SQL as Main Dataframe

conn = sqlite3.connect(r"C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db")

# Write the new DataFrame to a new SQLite table
DF.to_sql("MainAQMData", conn, if_exists="replace")
conn.close()
# Out:
# C:\Users\HPspectre\anaconda3new\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
df=DF_log.copy()
df_vif=DF_log.copy()
df = df.rename(columns={'FTSE 100': 'FTSE_100', 'FTSE 100_log': 'FTSE_100_log'})
dflog = df.drop(['BTC','BCH','LTC', 'ETH','EUR', 'CHF', 'GBP', 'RUB', 'YEN', 'SEK', 'Gold', 'Silver','Palladium','Platinum','OIL',
                'MSCI', 'FTSE_100','NASDAQ','DAX', 'SMI'], axis=1)

# %%
df.to_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\MainAQMData.csv')
df.to_excel(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\MainAQMData.xlsx')
dflog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 779 entries, 2021-01-01 to 2018-11-15
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BTC_log        778 non-null    float64
#  1   BCH_log        778 non-null    float64
#  2   LTC_log        778 non-null    float64
#  3   ETH_log        778 non-null    float64
#  4   EUR_log        778 non-null    float64
#  5   CHF_log        778 non-null    float64
#  6   GBP_log        778 non-null    float64
#  7   RUB_log        778 non-null    float64
#  8   YEN_log        778 non-null    float64
#  9   SEK_log        778 non-null    float64
#  10  Gold_log       778 non-null    float64
#  11  Silver_log     778 non-null    float64
#  12  Palladium_log  778 non-null    float64
#  13  Platinum_log   778 non-null    float64
#  14  OIL_log        778 non-null    float64
#  15  MSCI_log       778 non-null    float64
#  16  FTSE_100_log   778 non-null    float64
# ...

# %%
#Drop all non logaritmic Data
DF_olog=DF_log.drop(DF_header_list2, axis=1)

# %%
# Safe this LOG Dataframe -> Database SQL as Main Dataframe

conn = sqlite3.connect(r"C:\Users\HPspectre\Documents\Data\AQM Project\CSV Files\Programm\Database\AQM_Database.db")

# Write the new DataFrame to a new SQLite table
dflog.to_sql("LogMainAQMData", conn, if_exists="replace")
conn.close()

# %% [markdown]
# # Stationarity test of all variables

# %%
#Stationaritäts test
def test_stationarity(timeseries): #Perform Dickey-Fuller test: 
    print('Results of Dickey-Fuller Test:') 
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], 
                         index=['Test Statistic','p-value', 
                                '#Lags Used', 
                                'Number of Observations Used']) 
    for key,value in dftest[4].items(): 
        dfoutput['Critical Value (%s)'%key] = value 
        print(dfoutput)

# %%
#BTC_log
for i in DF_header_log_list:
    DF_log[i].plot(kind = 'line',
             legend = False,
             grid = True)
    plt.ylabel(i)
    plt.xlabel('Date')
    plt.show()
    test_stationarity(DF_log[i][1:])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -29.643286
# p-value                         0.000000
# #Lags Used                      0.000000
# Number of Observations Used   777.000000
# Critical Value (1%)            -3.438794
# dtype: float64
# Test Statistic                -29.643286
# p-value                         0.000000
# #Lags Used                      0.000000
# Number of Observations Used   777.000000
# Critical Value (1%)            -3.438794
# Critical Value (5%)            -2.865267
# dtype: float64
# Test Statistic                -29.643286
# p-value                         0.000000
# #Lags Used                      0.000000
# Number of Observations Used   777.000000
# Critical Value (1%)            -3.438794
# Critical Value (5%)            -2.865267
# Critical Value (10%)           -2.568755
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -12.391219
# p-value                         0.000000
# ...

# %%
#alle sind stationär

# %%
#test Correlation only between CO2

plt.figure(figsize=(40, 15)) 
mask=np.triu(np.ones_like(DF_olog.corr(), dtype=np.bool))
heatmap = sns.heatmap(DF_olog.corr(),mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':25}, pad=12);
#plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')

# %%
DF_log = DF_log.drop(DF_header_list2, axis=1)

# %% [markdown]
# # Start with the Regressions

# %%
df = df.copy()
#unrelevant regression - just to get different values of OLS that can be included in final output
y = df['BTC_log']
x = df[['Gold', 'Silver','Palladium','Platinum','OIL','MSCI', 'FTSE_100','NASDAQ','DAX', 'SMI']]
x = sm.add_constant(x)
model = sm.OLS(y,x, missing = 'drop') 
results = model.fit()

#list all different values that the results object of an OLS can return to select for loop
dir(results)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'eigenvals',
#  'el_test',
#  'ess',
# ...

# %%
dflog.columns
dflog=dflog.dropna()

# %%
target_variables_log = ['BTC_log', 'BCH_log', 'LTC_log', 'ETH_log','EUR_log', 'CHF_log', 'GBP_log', 'RUB_log', 'YEN_log', 'SEK_log']

#x = df[['Gold', 'Silver','Palladium','Platinum','OIL','MSCI', 'FTSE_100','NASDAQ','DAX', 'SMI']]
##x = sm.add_constant(x)

x = df[['Gold_log', 'Silver_log', 'Palladium_log', 'Platinum_log', 'OIL_log', 'MSCI_log', 'FTSE_100_log', 'NASDAQ_log', 'DAX_log', 'SMI_log']]
x = sm.add_constant(x)

explanatory_variables = x.columns

results_of_interest_log = []
for i in explanatory_variables: results_of_interest_log.append('params.'+i)
for i in explanatory_variables: results_of_interest_log.append('bse.'+i)
for i in explanatory_variables: results_of_interest_log.append('pvalues.'+i)    
    
results_of_interest_log.extend(('rsquared','rsquared_adj','aic','autocorrelation', 'heteroscedasticity_lm', 'heteroscedasticity_lm_pvalue'))#, 'multicollinearity'))
results_of_interest_log
# Out:
# ['params.const',
#  'params.Gold_log',
#  'params.Silver_log',
#  'params.Palladium_log',
#  'params.Platinum_log',
#  'params.OIL_log',
#  'params.MSCI_log',
#  'params.FTSE_100_log',
#  'params.NASDAQ_log',
#  'params.DAX_log',
#  'params.SMI_log',
#  'bse.const',
#  'bse.Gold_log',
#  'bse.Silver_log',
#  'bse.Palladium_log',
#  'bse.Platinum_log',
#  'bse.OIL_log',
#  'bse.MSCI_log',
#  'bse.FTSE_100_log',
#  'bse.NASDAQ_log',
#  'bse.DAX_log',
#  'bse.SMI_log',
#  'pvalues.const',
#  'pvalues.Gold_log',
#  'pvalues.Silver_log',
#  'pvalues.Palladium_log',
#  'pvalues.Platinum_log',
#  'pvalues.OIL_log',
#  'pvalues.MSCI_log',
#  'pvalues.FTSE_100_log',
#  'pvalues.NASDAQ_log',
#  'pvalues.DAX_log',
#  'pvalues.SMI_log',
#  'rsquared',
#  'rsquared_adj',
#  'aic',
#  'autocorrelation',
#  'heteroscedasticity_lm',
#  'heteroscedasticity_lm_pvalue']

# %%
# list/array with all regression combinations
regression_combinations_log = []

explanatory_variables_log = ['Gold_log', 'Silver_log','Palladium_log','Platinum_log','OIL_log','MSCI_log', 'FTSE_100_log','NASDAQ_log','DAX_log', 'SMI_log']
for n in range(0, len(explanatory_variables_log)+1):
    regression_combinations_log.extend(list(itertools.combinations(explanatory_variables_log, n)))

# %%
len(regression_combinations_log)
# Out:
# 1024

# %%
target_variables_log
# Out:
# ['BTC_log',
#  'BCH_log',
#  'LTC_log',
#  'ETH_log',
#  'EUR_log',
#  'CHF_log',
#  'GBP_log',
#  'RUB_log',
#  'YEN_log',
#  'SEK_log']

# %%
#creation of all rows
rows = []
for asset in target_variables_log: 
    for i in range(1,len(regression_combinations_log)+1): rows.append(asset+str(i))
        
len(rows)
# Out:
# 10240

# %%
# loop regression combination with rows

df_loop_log = pd.DataFrame(index=rows, columns=['y', 'x'])

for i in range(0,len(rows)):
    df_loop_log['y'][i] = target_variables_log[math.floor(i/len(regression_combinations_log))]
    df_loop_log['x'][i] = list(regression_combinations_log[int(math.remainder(i,len(regression_combinations_log)))])

df_loop_log
# Out:
#                    y                                                  x
# BTC_log1     BTC_log                                                 []
# BTC_log2     BTC_log                                         [Gold_log]
# BTC_log3     BTC_log                                       [Silver_log]
# BTC_log4     BTC_log                                    [Palladium_log]
# BTC_log5     BTC_log                                     [Platinum_log]
# ...              ...                                                ...
# SEK_log1020  SEK_log  [Gold_log, Silver_log, Palladium_log, OIL_log,...
# SEK_log1021  SEK_log  [Gold_log, Silver_log, Platinum_log, OIL_log, ...
# SEK_log1022  SEK_log  [Gold_log, Palladium_log, Platinum_log, OIL_lo...
# SEK_log1023  SEK_log  [Silver_log, Palladium_log, Platinum_log, OIL_...
# SEK_log1024  SEK_log  [Gold_log, Silver_log, Palladium_log, Platinum...
#
# [10240 rows x 2 columns]

# %%
#create empfty dataframe to fill during the loop
output_table_log = pd.DataFrame(index=rows, columns=results_of_interest_log)

#loop with regression of each asset over all 10 variables
for i in range(0,len(rows)):
        x = dflog[df_loop_log['x'][i]]
        x = sm.add_constant(x)
        y = dflog[df_loop_log['y'][i]]
        model = sm.OLS(y, x, missing = 'drop') 
        results = model.fit()

        for result in results_of_interest_log[:-3]:
            try: output_table_log[result][i] = eval("results."+result)
            except: pass

        output_table_log["autocorrelation"][i] = durbin_watson(results.resid)

        het = statsmodels.stats.diagnostic.het_breuschpagan(results.resid, exog_het = x)
        output_table_log["heteroscedasticity_lm"][i] = het[0]
        output_table_log["heteroscedasticity_lm_pvalue"][i] = het[1]

        #output_table["multicollinearity"][asset] = add function that returns multicollinearity

# %%
# Safe this Results -> Database SQL as Regression Results

conn = sqlite3.connect(r'C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db')

# Write the new DataFrame to a new SQLite table
output_table_log.to_sql("RegressionResults", conn, if_exists="replace")
conn.close()

# %%
output_table_log.to_csv(r'C:\Users\HPspectre\Desktop\AQM_Assignment\CSV_Files\output_table_log.csv')
output_table_log.head()
# Out:
#          params.const params.Gold_log params.Silver_log params.Palladium_log  \
# BTC_log1    -0.002156             NaN               NaN                  NaN
# BTC_log2    -0.001529        1.089562               NaN                  NaN
# BTC_log3    -0.001708             NaN          0.569069                  NaN
# BTC_log4    -0.001782             NaN               NaN             0.387806
# BTC_log5    -0.001968             NaN               NaN                  NaN
#
#          params.Platinum_log params.OIL_log params.MSCI_log  \
# BTC_log1                 NaN            NaN             NaN
# BTC_log2                 NaN            NaN             NaN
# BTC_log3                 NaN            NaN             NaN
# BTC_log4                 NaN            NaN             NaN
# BTC_log5            0.610004            NaN             NaN
#
#          params.FTSE_100_log params.NASDAQ_log params.DAX_log  ...  \
# BTC_log1                 NaN               NaN            NaN  ...
# ...

# %% [markdown]
# # Analyse der Regression

# %%
df=output_table_log.copy()
df.index.name='ID'
#df.reset_index().set_index('', drop=False)
df.head()
# Out:
#          params.const params.Gold_log params.Silver_log params.Palladium_log  \
# ID
# BTC_log1    -0.002156             NaN               NaN                  NaN
# BTC_log2    -0.001529        1.089562               NaN                  NaN
# BTC_log3    -0.001708             NaN          0.569069                  NaN
# BTC_log4    -0.001782             NaN               NaN             0.387806
# BTC_log5    -0.001968             NaN               NaN                  NaN
#
#          params.Platinum_log params.OIL_log params.MSCI_log  \
# ID
# BTC_log1                 NaN            NaN             NaN
# BTC_log2                 NaN            NaN             NaN
# BTC_log3                 NaN            NaN             NaN
# BTC_log4                 NaN            NaN             NaN
# BTC_log5            0.610004            NaN             NaN
#
#          params.FTSE_100_log params.NASDAQ_log params.DAX_log  ...  \
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#                 ID params.const params.Gold_log params.Silver_log  \
# 0         BTC_log1    -0.002156             NaN               NaN
# 1         BTC_log2    -0.001529        1.089562               NaN
# 2         BTC_log3    -0.001708             NaN          0.569069
# 3         BTC_log4    -0.001782             NaN               NaN
# 4         BTC_log5    -0.001968             NaN               NaN
# ...            ...          ...             ...               ...
# 10235  SEK_log1020    -0.000004       -0.089440         -0.027327
# 10236  SEK_log1021     0.000029       -0.076915          0.007738
# 10237  SEK_log1022     0.000024       -0.064444               NaN
# 10238  SEK_log1023     0.000046             NaN         -0.017948
# 10239  SEK_log1024     0.000023       -0.076057          0.008852
#
#       params.Palladium_log params.Platinum_log params.OIL_log params.MSCI_log  \
# 0                      NaN                 NaN            NaN             NaN
# ...

# %%
# separate all Data into new Dataframes
dfBTC = df.loc[df['ID'].str.startswith('BTC')].copy()
dfBCH = df.loc[df['ID'].str.startswith('BCH')].copy()
dfLTC = df.loc[df['ID'].str.startswith('LTC')].copy()
dfETH = df.loc[df['ID'].str.startswith('ETH')].copy()
dfEUR= df.loc[df['ID'].str.startswith('EUR')].copy()
dfCHF = df.loc[df['ID'].str.startswith('CHF')].copy()
dfGBP = df.loc[df['ID'].str.startswith('GBP')].copy()
dfRUB = df.loc[df['ID'].str.startswith('RUB')].copy()
dfYEN = df.loc[df['ID'].str.startswith('YEN')].copy()
dfSEK= df.loc[df['ID'].str.startswith('SEK')].copy()

# %%
df
# Out:
#                 ID params.const params.Gold_log params.Silver_log  \
# 0         BTC_log1    -0.002156             NaN               NaN
# 1         BTC_log2    -0.001529        1.089562               NaN
# 2         BTC_log3    -0.001708             NaN          0.569069
# 3         BTC_log4    -0.001782             NaN               NaN
# 4         BTC_log5    -0.001968             NaN               NaN
# ...            ...          ...             ...               ...
# 10235  SEK_log1020    -0.000004       -0.089440         -0.027327
# 10236  SEK_log1021     0.000029       -0.076915          0.007738
# 10237  SEK_log1022     0.000024       -0.064444               NaN
# 10238  SEK_log1023     0.000046             NaN         -0.017948
# 10239  SEK_log1024     0.000023       -0.076057          0.008852
#
#       params.Palladium_log params.Platinum_log params.OIL_log params.MSCI_log  \
# 0                      NaN                 NaN            NaN             NaN
# ...

# %% [markdown]
# # Analysis of BTC

# %%
dfBTC.set_index('ID', inplace=True)
dfBTC=dfBTC[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfBTC.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfBTC.head()
# Out:
#             rsquared_adj          aic autocorrelation  \
# ID
# BTC_log859      0.093838 -2929.544443        2.121439
# BTC_log979      0.093615 -2928.364147        2.119788
# BTC_log1019     0.093588 -2927.353543        2.105656
# BTC_log989      0.093321 -2928.111845        2.105553
# BTC_log980      0.093113 -2927.933345        2.113528
#
#             heteroscedasticity_lm_pvalue
# ID
# BTC_log859                      0.000000
# BTC_log979                      0.000000
# BTC_log1019                     0.000000
# BTC_log989                      0.000000
# BTC_log980                      0.000000

# %% [markdown]
# # Analysis of BCH

# %%
dfBCH.set_index('ID', inplace=True)
dfBCH=dfBCH[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfBCH.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfBCH.head()
# Out:
#             rsquared_adj          aic autocorrelation  \
# ID
# BCH_log916      0.052869 -2224.028143        1.866285
# BCH_log1002     0.052642 -2222.852846        1.864550
# BCH_log998      0.051704 -2222.083086        1.865558
# BCH_log980      0.051638 -2222.028497        1.866247
# BCH_log1022     0.051553 -2220.971337        1.863387
#
#             heteroscedasticity_lm_pvalue
# ID
# BCH_log916                      0.002758
# BCH_log1002                     0.003916
# BCH_log998                      0.005479
# BCH_log980                      0.004827
# BCH_log1022                     0.007732

# %% [markdown]
# # Analysis of LTC

# %%
dfLTC.set_index('ID', inplace=True)
dfLTC=dfLTC[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfLTC.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfLTC.head()
# Out:
#            rsquared_adj          aic autocorrelation  \
# ID
# LTC_log449     0.069688 -2384.330718        2.166213
# LTC_log916     0.069563 -2382.243710        2.160217
# LTC_log723     0.069432 -2383.124580        2.156528
# LTC_log645     0.069278 -2382.995772        2.166490
# LTC_log863     0.069150 -2381.899026        2.156008
#
#            heteroscedasticity_lm_pvalue
# ID
# LTC_log449                     0.008632
# LTC_log916                     0.023206
# LTC_log723                     0.019481
# LTC_log645                     0.002363
# LTC_log863                     0.005641

# %% [markdown]
# # Analysis of ETH

# %%
dfETH.set_index('ID', inplace=True)
cols = list(dfETH.columns.values)
dfETH=dfETH[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfETH.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfETH.head()
# Out:
#             rsquared_adj          aic autocorrelation  \
# ID
# ETH_log1002     0.074711 -2519.003193        2.180549
# ETH_log989      0.074576 -2518.889602        2.178902
# ETH_log916      0.074543 -2519.851247        2.180622
# ETH_log1019     0.074233 -2517.613300        2.179653
# ETH_log980      0.074176 -2518.553701        2.179709
#
#             heteroscedasticity_lm_pvalue
# ID
# ETH_log1002                     0.000000
# ETH_log989                      0.000000
# ETH_log916                      0.000000
# ETH_log1019                     0.000000
# ETH_log980                      0.000000

# %% [markdown]
# # Analysis of EUR

# %%
dfEUR.set_index('ID', inplace=True)
dfEUR=dfEUR[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfEUR.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfEUR.head()
# Out:
#            rsquared_adj          aic autocorrelation  \
# ID
# EUR_log888     0.246729 -6869.567112        2.040197
# EUR_log884     0.246673 -6869.508835        2.030583
# EUR_log991     0.246422 -6868.261074        2.041587
# EUR_log675     0.246012 -6869.816385        2.020468
# EUR_log969     0.245952 -6867.775256        2.031454
#
#            heteroscedasticity_lm_pvalue
# ID
# EUR_log888                     0.000051
# EUR_log884                     0.000079
# EUR_log991                     0.000124
# EUR_log675                     0.000028
# EUR_log969                     0.000080

# %% [markdown]
# # Analysis of CHF

# %%
dfCHF.set_index('ID', inplace=True)
cols = list(dfCHF.columns.values)
dfCHF=dfCHF[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfCHF.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfCHF.head()
# Out:
#             rsquared_adj          aic autocorrelation  \
# ID
# CHF_log990      0.287724 -6878.405137        1.958093
# CHF_log884      0.287605 -6879.264032        1.960305
# CHF_log969      0.287492 -6878.151190        1.962164
# CHF_log1014     0.287462 -6877.131074        1.959731
# CHF_log1021     0.287191 -6876.835032        1.950205
#
#             heteroscedasticity_lm_pvalue
# ID
# CHF_log990                      0.021817
# CHF_log884                      0.006242
# CHF_log969                      0.015299
# CHF_log1014                     0.042775
# CHF_log1021                     0.020376

# %% [markdown]
# # Analysis of GBP

# %%
dfGBP.set_index('ID', inplace=True)
cols = list(dfGBP.columns.values)
dfGBP=dfGBP[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfGBP.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfGBP.head()
# Out:
#            rsquared_adj          aic autocorrelation  \
# ID
# GBP_log711     0.174499 -6160.731598        1.956020
# GBP_log906     0.173623 -6158.916100        1.949706
# GBP_log851     0.173493 -6158.793114        1.957163
# GBP_log908     0.173436 -6158.739783        1.955653
# GBP_log910     0.173431 -6158.735071        1.956444
#
#            heteroscedasticity_lm_pvalue
# ID
# GBP_log711                     0.000001
# GBP_log906                     0.000003
# GBP_log851                     0.000001
# GBP_log908                     0.000003
# GBP_log910                     0.000000

# %% [markdown]
# # Analysis of RUB

# %%
dfRUB.set_index('ID', inplace=True)
cols = list(dfRUB.columns.values)
dfRUB=dfRUB[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfRUB.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfRUB.head()
# Out:
#             rsquared_adj          aic autocorrelation  \
# ID
# RUB_log1004     0.348215 -5684.133762        2.137970
# RUB_log1022     0.347856 -5682.717358        2.135739
# RUB_log1021     0.347385 -5682.155333        2.138317
# RUB_log927      0.347087 -5683.776962        2.131333
# RUB_log1024     0.347037 -5680.754361        2.136127
#
#             heteroscedasticity_lm_pvalue
# ID
# RUB_log1004                     0.000000
# RUB_log1022                     0.000000
# RUB_log1021                     0.000000
# RUB_log927                      0.000000
# RUB_log1024                     0.000000

# %%
# Analysis of YEN

# %%
dfYEN.set_index('ID', inplace=True)
cols = list(dfYEN.columns.values)
dfYEN=dfYEN[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfYEN.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfYEN.head()
# Out:
#             rsquared_adj          aic autocorrelation  \
# ID
# YEN_log989      0.440989 -6838.745720        2.062578
# YEN_log879      0.440934 -6839.658329        2.063085
# YEN_log984      0.440514 -6838.084896        2.065507
# YEN_log1020     0.440475 -6837.042820        2.064546
# YEN_log1019     0.440335 -6836.848961        2.064408
#
#             heteroscedasticity_lm_pvalue
# ID
# YEN_log989                      0.000000
# YEN_log879                      0.000000
# YEN_log984                      0.000000
# YEN_log1020                     0.000000
# YEN_log1019                     0.000000

# %% [markdown]
# # Analysis of SEK

# %%
dfSEK.set_index('ID', inplace=True)
cols = list(dfSEK.columns.values)
dfSEK=dfSEK[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfSEK.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfSEK.head()
# Out:
#             rsquared_adj          aic autocorrelation  \
# ID
# SEK_log1022     0.222847 -6307.233784        2.005763
# SEK_log998      0.222675 -6308.048694        1.992545
# SEK_log1004     0.222457 -6307.831100        2.011297
# SEK_log1024     0.222160 -6305.559481        2.007526
# SEK_log927      0.221999 -6308.361112        1.996829
#
#             heteroscedasticity_lm_pvalue
# ID
# SEK_log1022                     0.000000
# SEK_log998                      0.000932
# SEK_log1004                     0.000000
# SEK_log1024                     0.000000
# SEK_log927                      0.000791

# %% [markdown]
# # New Dataframe with highest adjusted R^2

# %%
DF = pd.DataFrame(columns=['rsquared_adj', 'aic','autocorrelation','heteroscedasticity_lm_pvalue'])
DF
# Out:
# Empty DataFrame
# Columns: [rsquared_adj, aic, autocorrelation, heteroscedasticity_lm_pvalue]
# Index: []

# %%
DF=DF.append(dfBTC.head(1))
DF=DF.append(dfBCH.head(1))
DF=DF.append(dfLTC.head(1))
DF=DF.append(dfETH.head(1))
DF=DF.append(dfEUR.head(1))
DF=DF.append(dfCHF.head(1))
DF=DF.append(dfGBP.head(1))
DF=DF.append(dfRUB.head(1))
DF=DF.append(dfYEN.head(1))
DF=DF.append(dfSEK.head(1))
DF.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
DF
# Out:
#             rsquared_adj          aic autocorrelation  \
# YEN_log989      0.440989 -6838.745720        2.062578
# RUB_log1004     0.348215 -5684.133762        2.137970
# CHF_log990      0.287724 -6878.405137        1.958093
# EUR_log888      0.246729 -6869.567112        2.040197
# SEK_log1022     0.222847 -6307.233784        2.005763
# GBP_log711      0.174499 -6160.731598        1.956020
# BTC_log859      0.093838 -2929.544443        2.121439
# ETH_log1002     0.074711 -2519.003193        2.180549
# LTC_log449      0.069688 -2384.330718        2.166213
# BCH_log916      0.052869 -2224.028143        1.866285
#
#             heteroscedasticity_lm_pvalue
# YEN_log989                      0.000000
# RUB_log1004                     0.000000
# CHF_log990                      0.021817
# EUR_log888                      0.000051
# SEK_log1022                     0.000000
# GBP_log711                      0.000001
# BTC_log859                      0.000000
# ...

# %%
# Safe this Results -> Database SQL as HighestadjR^2Results 

conn = sqlite3.connect(r'C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db')

# Write the new DataFrame to a new SQLite table
DF.to_sql("HighestadjR^2Results", conn, if_exists="replace")
conn.close()

# %% [markdown]
# # heteroskedasticity is found in all main results: where only p-Values of heteroskedasty bigger than 0.5

# %%
dfH = df[df.heteroscedasticity_lm_pvalue>0.05]

# %%
dfBTC = dfH.loc[df['ID'].str.startswith('BTC')].copy()
dfBCH = dfH.loc[df['ID'].str.startswith('BCH')].copy()
dfLTC = dfH.loc[df['ID'].str.startswith('LTC')].copy()
dfETH = dfH.loc[df['ID'].str.startswith('ETH')].copy()
dfEUR= dfH.loc[df['ID'].str.startswith('EUR')].copy()
dfCHF = dfH.loc[df['ID'].str.startswith('CHF')].copy()
dfGBP = dfH.loc[df['ID'].str.startswith('GBP')].copy()
dfRUB = dfH.loc[df['ID'].str.startswith('RUB')].copy()
dfYEN = dfH.loc[df['ID'].str.startswith('YEN')].copy()
dfSEK= dfH.loc[df['ID'].str.startswith('SEK')].copy()

# %%
dfBTC.set_index('ID', inplace=True)
dfBTC=dfBTC[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfBTC.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfBCH.set_index('ID', inplace=True)
dfBCH=dfBCH[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfBCH.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfLTC.set_index('ID', inplace=True)
dfLTC=dfLTC[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfLTC.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfETH.set_index('ID', inplace=True)
cols = list(dfETH.columns.values)
dfETH=dfETH[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfETH.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)

dfEUR.set_index('ID', inplace=True)
dfEUR=dfEUR[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfEUR.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfCHF.set_index('ID', inplace=True)
cols = list(dfCHF.columns.values)
dfCHF=dfCHF[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfCHF.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfGBP.set_index('ID', inplace=True)
cols = list(dfGBP.columns.values)
dfGBP=dfGBP[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfGBP.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfRUB.set_index('ID', inplace=True)
cols = list(dfRUB.columns.values)
dfRUB=dfRUB[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfRUB.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfYEN.set_index('ID', inplace=True)
cols = list(dfYEN.columns.values)
dfYEN=dfYEN[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfYEN.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
dfSEK.set_index('ID', inplace=True)
cols = list(dfSEK.columns.values)
dfSEK=dfSEK[['rsquared_adj','aic','autocorrelation','heteroscedasticity_lm_pvalue']]
dfSEK.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)

# %%
DFn = pd.DataFrame(columns=['rsquared_adj', 'aic','autocorrelation','heteroscedasticity_lm_pvalue'])

# %%
DFn=DFn.append(dfBTC.head(1))
DFn=DFn.append(dfBCH.head(1))
DFn=DFn.append(dfLTC.head(1))
DFn=DFn.append(dfETH.head(1))
DFn=DFn.append(dfEUR.head(1))
DFn=DFn.append(dfCHF.head(1))
DFn=DFn.append(dfGBP.head(1))
DFn=DFn.append(dfRUB.head(1))
DFn=DFn.append(dfYEN.head(1))
DFn=DFn.append(dfSEK.head(1))

# %%
DFn.sort_values(by=['rsquared_adj'], ascending=False, inplace = True)
DFn= DFn.rename(columns={'rsquared_adj': 'aR^2', 'aic': 'AIC','autocorrelation': 'autocorr','heteroscedasticity_lm_pvalue': 'Heteroscedasticity' })
DFn
# Out:
#                  aR^2          AIC autocorr Heteroscedasticity
# CHF_log979   0.286845 -6877.445673 1.958339           0.050020
# SEK_log935   0.206891 -6293.398485 2.021412           0.054648
# EUR_log214   0.143564 -6772.681685 1.983096           0.360645
# GBP_log326   0.140072 -6130.927643 1.902026           0.164376
# LTC_log1000  0.068154 -2380.077490 2.149753           0.090953
# BCH_log493   0.046028 -2220.411053 1.872308           0.062811
# YEN_log9     0.033102 -6419.411463 2.171020           0.537221
# RUB_log7     0.032584 -5383.840206 2.032409           0.216099
# ETH_log11    0.001587 -2466.777683 2.157394           0.059710
# BTC_log11   -0.000901 -2858.143646 2.111705           0.059187

# %%
# Safe this Results -> Database SQL as HighestadjR^2Results cleand Heteroskedasticity

conn = sqlite3.connect(r'C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db')

# Write the new DataFrame to a new SQLite table
DF.to_sql("HighestadjR^2ResultsCleanHeteroskedasticity", conn, if_exists="replace")
conn.close()

# %% [markdown]
# # VIF Calculation

# %%
df_vif = df_vif.rename(columns={'FTSE 100': 'FTSE_100', 'FTSE 100_log': 'FTSE_100_log'})
dflog_vif = df_vif.drop(['BTC','BCH','LTC', 'ETH','EUR', 'CHF', 'GBP', 'RUB', 'YEN', 'SEK', 'Gold', 'Silver','Palladium','Platinum','OIL',
                'MSCI', 'FTSE_100','NASDAQ','DAX', 'SMI'], axis=1)
dflog_vif.dropna(inplace=True)
dflog_vif
# Out:
#              BTC_log   BCH_log   LTC_log   ETH_log   EUR_log   CHF_log  \
# Date
# 2020-12-31 -0.009362  0.010226 -0.011779  0.012461  0.000082  0.000000
# 2020-12-30 -0.002646  0.036381  0.027427  0.012508  0.006692 -0.004643
# 2020-12-29 -0.072352 -0.020447 -0.010643 -0.032383 -0.003912  0.003739
# 2020-12-28 -0.011528  0.027003  0.022260  0.003322 -0.002698  0.004626
# 2020-12-27  0.006147 -0.031632  0.016452 -0.053952 -0.000819  0.000563
# ...              ...       ...       ...       ...       ...       ...
# 2018-11-19  0.095864  0.215871  0.100923  0.118904  0.007099 -0.001308
# 2018-11-18  0.145611  0.177003  0.157145  0.185688 -0.002886  0.006221
# 2018-11-17 -0.007897  0.011464 -0.008889 -0.030752  0.000000  0.000000
# 2018-11-16 -0.006520 -0.012008  0.007453  0.016725  0.000000  0.000000
# 2018-11-15  0.003739  0.015690  0.038760  0.013407 -0.008090  0.007176
#
#              GBP_log   RUB_log   YEN_log   SEK_log  Gold_log  Silver_log  \
# Date
# ...

# %%
# independent Variables
X = dflog_vif[['Gold_log', 'Silver_log', 'Palladium_log','Platinum_log', 'OIL_log',
          'MSCI_log', 'FTSE_100_log', 'NASDAQ_log', 'DAX_log', 'SMI_log']]
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]

# %%
vif_data.set_index(['feature'])
# Out:
#                    VIF
# feature
# Gold_log      2.631759
# Silver_log    3.319487
# Palladium_log 1.569880
# Platinum_log  2.151781
# OIL_log       1.147481
# MSCI_log      3.159347
# FTSE_100_log  3.343956
# NASDAQ_log    1.880178
# DAX_log       2.072831
# SMI_log       2.491285

# %%
# Safe this Results -> Database SQL as VIF Results

conn = sqlite3.connect(r'C:\Users\HPspectre\Desktop\AQM_Assignment\Database\AQM_Database.db')

# Write the new DataFrame to a new SQLite table
DF.to_sql("VIF_Results", conn, if_exists="replace")
conn.close()
